# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
path = '/home/vmuser/Downloads/train/'

folders = []
files = []
#myfiles = []

# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for folder in d:
        folders.append(os.path.join(r, folder))
        
for a in folders:
    for r, d, f in os.walk(a):
        myfiles = []
        for file in f:
            if '.jpg' in file:
                #print("soka")
                myfiles.append(os.path.join(r, file))
    files.append(myfiles)
            
# r=root, d=directories, f = files
#for r, d, f in os.walk(path):
#    #for folder in d:
#    for file in f:
#        if '.jpg' in file:
#            print("ok")
#            files.append(os.path.join(r, file))

for f in folders:
    print(f)

#print(len(files[0]))
for f in files:
    print(len(f))
# Out:
# /home/vmuser/Downloads/train/class-581
# /home/vmuser/Downloads/train/class-854
# /home/vmuser/Downloads/train/class-957
# /home/vmuser/Downloads/train/class-1625
# /home/vmuser/Downloads/train/class-804
# /home/vmuser/Downloads/train/class-639
# /home/vmuser/Downloads/train/class-72
# /home/vmuser/Downloads/train/class-460
# /home/vmuser/Downloads/train/class-734
# /home/vmuser/Downloads/train/class-707
# /home/vmuser/Downloads/train/class-128
# /home/vmuser/Downloads/train/class-663
# /home/vmuser/Downloads/train/class-653
# /home/vmuser/Downloads/train/class-857
# /home/vmuser/Downloads/train/class-543
# /home/vmuser/Downloads/train/class-450
# /home/vmuser/Downloads/train/class-67
# /home/vmuser/Downloads/train/class-326
# /home/vmuser/Downloads/train/class-78
# /home/vmuser/Downloads/train/class-273
# /home/vmuser/Downloads/train/class-508
# /home/vmuser/Downloads/train/class-239
# /home/vmuser/Downloads/train/class-1059
# /home/vmuser/Downloads/train/class-4
# /home/vmuser/Downloads/train/class-540
# /home/vmuser/Downloads/train/class-771
# /home/vmuser/Downloads/train/class-629
# /home/vmuser/Downloads/train/class-966
# /home/vmuser/Downloads/train/class-390
# /home/vmuser/Downloads/train/class-204
# /home/vmuser/Downloads/train/class-697
# /home/vmuser/Downloads/train/class-784
# /home/vmuser/Downloads/train/class-536
# /home/vmuser/Downloads/train/class-337
# /home/vmuser/Downloads/train/class-872
# /home/vmuser/Downloads/train/class-394
# /home/vmuser/Downloads/train/class-561
# /home/vmuser/Downloads/train/class-811
# /home/vmuser/Downloads/train/class-635
# /home/vmuser/Downloads/train/class-362
# /home/vmuser/Downloads/train/class-654
# /home/vmuser/Downloads/train/class-526
# /home/vmuser/Downloads/train/class-140
# /home/vmuser/Downloads/train/class-597
# /home/vmuser/Downloads/train/class-448
# 1908
# 1773
# 605
# 1677
# 2555
# 2183
# 852
# 1394
# 593
# 1148
# 749
# 961
# 715
# 1138
# 1383
# 1003
# 3201
# 639
# 2149
# 583
# 2068
# 677
# 890
# 1500
# 1053
# 5536
# 527
# 1471
# 2295
# 11092
# 4619
# 517
# 1368
# 3472
# 5525
# 1232
# 531
# 910
# 1186
# 2154
# 1071
# 629
# 1498
# 1006
# 2565
